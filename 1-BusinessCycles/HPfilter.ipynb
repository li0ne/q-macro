# %% [markdown]
# <a href="https://colab.research.google.com/github/li0ne/q-macro/blob/main/1-BusinessCycles/HPfilter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import pandas_datareader.data as web
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pandas_datareader as pdr
import numpy as np
import plotly.graph_objects as go
from plotly.offline import plot

# set the start and end dates for the data
start_date = '1994-01-01'
end_date = '2022-01-01'

# download the data from FRED using pandas_datareader
gdp_us = web.DataReader('GDPC1', 'fred', start_date, end_date)
gdp_jp = web.DataReader('JPNRGDPEXO', 'fred', start_date, end_date)

# take the log of the GDP data
log_gdp_us = np.log(gdp_us)
log_gdp_us = np.log(gdp_jp)

# calculate the quarterly percent change in real GDP
gdp_pct_change_us = gdp_us.pct_change(4)
gdp_pct_change_jp = gdp_jp.pct_change(4)

# apply a Hodrick-Prescott filter to the data to extract the cyclical component
cycle_us, trend_us = sm.tsa.filters.hpfilter(log_gdp_us, lamb=1600)
cycle_us, trend_jp = sm.tsa.filters.hpfilter(log_gdp_jp, lamb=1600)

#create an interactive
fig = go.Figure()
fig2 = go.Figure()

# Plot the trend component
plt.plot(trend, label="Trend")

# Add a legend and show the plot
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# RemoteDataError                           Traceback (most recent call last)
# <ipython-input-1-ad0eda5f02a3> in <cell line: 16>()
#      14 # download the data from FRED using pandas_datareader
#      15 gdp_us = web.DataReader('GDPC1', 'fred', start_date, end_date)
# ---> 16 gdp_jp = web.DataReader('JPNRGDPEXO', 'fred', start_date, end_date)
#      17
#      18 # take the log of the GDP data
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     208                     raise TypeError(msg)
#     209                 kwargs[new_arg_name] = new_arg_value
# --> 210             return func(*args, **kwargs)
#     211
#     212         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas_datareader/data.py in DataReader(name, data_source, start, end, retry_count, pause, session, api_key)
#     454             pause=pause,
# ...

# %%
# Plot the cycle component
plt.plot(cycle, label="Cyclical component")

# Add a legend and show the plot
plt.legend()
plt.show()

cycle_mean = cycle.mean()
cycle_std = cycle.std()

print("Cycle mean:", cycle_mean)
print("Cycle standard deviation:", cycle_std)
# Out:
# Cycle mean: -1.2989857021502723e-13
# Cycle standard deviation: 0.015382726767609416
